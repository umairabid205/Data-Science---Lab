# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df= pd.read_csv('/content/educ_figdp_1_Data.csv', usecols = ['TIME','GEO','Value'])

# %%
df.head()
# Out:
#    TIME                            GEO Value
# 0  2000  European Union (28 countries)     :
# 1  2001  European Union (28 countries)     :
# 2  2002  European Union (28 countries)  5.00
# 3  2003  European Union (28 countries)  5.03
# 4  2004  European Union (28 countries)  4.95

# %%
df.tail()
# Out:
#      TIME      GEO Value
# 379  2007  Finland  5.90
# 380  2008  Finland  6.10
# 381  2009  Finland  6.81
# 382  2010  Finland  6.85
# 383  2011  Finland  6.76

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 384 entries, 0 to 383
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   TIME    384 non-null    int64
#  1   GEO     384 non-null    object
#  2   Value   384 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 9.1+ KB

# %%
# There was some messy values in data to I replaced them with 0
df['Value'] = df['Value'].replace(':',0)

# %%
# as we can see above df.info() the dtype of Value col is object thats is why I changed dtype
df['Value'] = df['Value'].astype('float64')

# %%
df.describe()
# Out:
#               TIME       Value
# count   384.000000  384.000000
# mean   2005.500000    4.892292
# std       3.456556    1.584320
# min    2000.000000    0.000000
# 25%    2002.750000    4.427500
# 50%    2005.500000    5.020000
# 75%    2008.250000    5.620000
# max    2011.000000    8.810000

# %%
df['Value'].isna().sum()
# Out:
# 0

# %%
df['Value'].describe()
# Out:
# count    384.000000
# mean       4.892292
# std        1.584320
# min        0.000000
# 25%        4.427500
# 50%        5.020000
# 75%        5.620000
# max        8.810000
# Name: Value, dtype: float64

# %%
import random
random_numbers = random.sample(range(0,380),38)
random_rows = df.iloc[random_numbers]

# %%
random_rows
# Out:
#      TIME                            GEO Value
# 191  2011                          Spain  4.82
# 376  2004                        Finland  6.42
# 262  2010                     Luxembourg     :
# 185  2005                          Spain  4.23
# 82   2010       Euro area (13 countries)  5.28
# 279  2003                          Malta  4.48
# 67   2007       Euro area (15 countries)  4.81
# 354  2006                       Slovenia  5.72
# 63   2003       Euro area (15 countries)  5.04
# 194  2002                         France  5.90
# 350  2002                       Slovenia  5.76
# 31   2007  European Union (25 countries)  4.95
# 342  2006                        Romania     :
# 38   2002       Euro area (18 countries)  4.87
# 129  2009                        Denmark  8.74
# 374  2002                        Finland  6.22
# 53   2005       Euro area (17 countries)  4.72
# 84   2000                        Belgium     :
# 170  2002                         Greece  3.57
# ...

# %%
random_rows.isnull().sum()
# Out:
# TIME     0
# GEO      0
# Value    0
# dtype: int64

# %%
random_rows['Value'].describe()
# Out:
# count     38
# unique    31
# top        :
# freq       3
# Name: Value, dtype: object

# %%
fill = random_rows.fillna(999)

# %%
fill.replace(999,5.06)
# Out:
#      TIME                            GEO Value
# 191  2011                          Spain  4.82
# 376  2004                        Finland  6.42
# 262  2010                     Luxembourg     :
# 185  2005                          Spain  4.23
# 82   2010       Euro area (13 countries)  5.28
# 279  2003                          Malta  4.48
# 67   2007       Euro area (15 countries)  4.81
# 354  2006                       Slovenia  5.72
# 63   2003       Euro area (15 countries)  5.04
# 194  2002                         France  5.90
# 350  2002                       Slovenia  5.76
# 31   2007  European Union (25 countries)  4.95
# 342  2006                        Romania     :
# 38   2002       Euro area (18 countries)  4.87
# 129  2009                        Denmark  8.74
# 374  2002                        Finland  6.22
# 53   2005       Euro area (17 countries)  4.72
# 84   2000                        Belgium     :
# 170  2002                         Greece  3.57
# ...

# %%
df['Scaled_Values'] = (df['Value'] - df['Value'].min()) / (df['Value'].max() - df['Value'].min())
df['Scaled_Values1'] = (df['Value'] - df['Value'].mean()) / df['Value'].std()

# %%
df.head()
# Out:
#    TIME                            GEO  Value  Scaled_Values  Scaled_Values1
# 0  2000  European Union (28 countries)   0.00       0.000000       -3.087945
# 1  2001  European Union (28 countries)   0.00       0.000000       -3.087945
# 2  2002  European Union (28 countries)   5.00       0.567537        0.067984
# 3  2003  European Union (28 countries)   5.03       0.570942        0.086920
# 4  2004  European Union (28 countries)   4.95       0.561862        0.036425
